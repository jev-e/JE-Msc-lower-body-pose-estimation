# %%
from mpl_toolkits import mplot3d
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


fig = plt.figure()
ax = plt.axes(projection='3d')


coords = pd.read_csv("../trim_output/jumping_1_trimmed.csv")

x_pos = coords.filter(regex=("x"))
y_pos = coords.filter(regex=("y"))
z_pos = coords.filter(regex=("z"))

y_pos_first = y_pos.iloc[0]
x_pos_first = x_pos.iloc[0]
z_pos_first = z_pos.iloc[0]

# %%
jumping_data = pd.read_csv("../trim_output/jumping_1_trimmed.csv")
raise_arm_data = pd.read_csv("../trim_output/arm_raise_1_trimmed.csv")
walking_data = pd.read_csv("../trim_output/walking_1_train.csv")
sitting_data = pd.read_csv("../trim_output/sitting_standing_1_trimmed.csv")
jumping_data.plot(figsize=(10,5), title = 'Jumping Data')
walking_data.plot(figsize=(10,5), title = 'Walking Data')
raise_arm_data.plot(figsize=(10,5), title = 'Arm Raise Data')
sitting_data.plot(figsize=(10,5), title = 'Sitting Data')
# Out:
# <AxesSubplot:title={'center':'Arm Raise Data'}>

# %%
from mpl_toolkits import mplot3d


# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
x_val =  (-4.6/10, 20.5/10, -26.3/10, -4.2/10, 20.2/10, -20.6/10)
y_val = (155.3/10, 78.7/10, 77.10/10, 95.60/10, 5.7/10, 6.07/10)
z_val = (-13.05/10, -15.8/10, -14.8/10, -12.1/10, -0.8/10, -2.5/10)
ax.set_xlim3d(-2.5, 2.5)
ax.set_ylim3d(-2.5, 2.5)
ax.set_zlim3d(-2.5, 2.5)

ax.scatter(x_val, y_val, z_val)
